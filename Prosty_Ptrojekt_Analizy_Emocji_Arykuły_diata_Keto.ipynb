# %% [markdown]
# # 📊 Analiza sentymentu artykułów o diecie ketogenicznej
#
# ## Opis projektu
#
# Projekt polega na analizie sentymentu 6 artykułów dotyczących diety ketogenicznej, pochodzących z popularnych polskich portali:
# - Onet
# - WP
# - Trójmiasto.pl
# - Narodowe Centrum Edukacji Żywieniowej
#
# Program w języku **Python** automatycznie wyszukuje pliki `.txt`, odczytuje ich treść i wysyła tekst do API wykorzystującego model językowy dla języka polskiego.
# Autoryzacja odbywa się za pomocą **Bearer Token**.
#
# Na podstawie odpowiedzi API wyświetlany jest:
# - typ sentymentu (*pozytywny / negatywny / bardzo negatywny*),
# - poziom pewności klasyfikacji.

# %% [markdown]
# # 📈 Wyniki analizy
#
# | NAZWA PLIKU | SENTYMENT         | PEWNOŚĆ |
# |-------------|-------------------|---------|
# | text.txt    | BARDZO NEGATYWNY  | 58.77%  |
# | text1.txt   | BARDZO NEGATYWNY  | 32.07%  |
# | text2.txt   | NEGATYWNY         | 29.89%  |
# | text3.txt   | BARDZO NEGATYWNY  | 58.77%  |
# | text4.txt   | POZYTYWNY         | 31.01%  |
# | text5.txt   | NEGATYWNY         | 30.38%  |
#
# ---
#
# ## 🧠 Wnioski
#
# - Większość analizowanych artykułów ma negatywny wydźwięk wobec diety ketogenicznej.
# - Tylko jeden artykuł został sklasyfikowany jako pozytywny.
# - Poziomy pewności wskazują umiarkowaną jednoznaczność klasyfikacji (30–60%).
# - Może to sugerować, że media częściej przedstawiają dietę keto w kontekście zagrożeń lub kontrowersji.
